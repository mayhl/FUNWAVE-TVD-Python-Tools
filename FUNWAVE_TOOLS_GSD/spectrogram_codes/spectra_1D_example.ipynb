# %% [markdown]
# ##### Import Library

# %%
import spectra_1D as sp_1d
import numpy as np
import scipy as sp
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Create Dummy Input Signal

# %%
"""input parameters"""
freq = 0.2 # frequency
duration = 1024 # total duration of the TS, duration = N*dt
fs = 2 # sampling frequency
"""Step 1: generating a time vector from 0 to (duration - dt), equally spaced"""
dt = 1/fs # time difference between consecutive samples
t = np.arange(0,duration,dt) # time

"""Step 2: generating a water surface TS with an amplitude of -.5m  and a frequency
of 0.2Hz (period = 5sec)"""
Eta = 0.5*np.cos(2*np.pi*freq*t)
rnd = 0.01+(0.1-(-0.1))*np.random.rand(len(t)) # uniformly distributed random signal [-0.1m and 0.1m]
Eta = Eta+rnd # adding random signal to sinosoidal signal

# %% [markdown]
# ##### Call 1D Spectra Code & Plot

# %%
# Compute 1 Sided PSD
f, psd_data = sp_1d.compute_spectra_1D(Eta, fs) # Returns f, psd_1_sided
# Plot 1 Sided PSD
sp_1d.plot_spectra_1D(Eta, t, f, psd_data, 'Surface Elevation', 'm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21436\3027543574.py in <module>
#       2 f, psd_data = sp_1d.compute_spectra_1D(Eta, fs) # Returns f, psd_1_sided
#       3 # Plot 1 Sided PSD
# ----> 4 sp_1d.plot_spectra_1D(Eta, t, f, psd_data, 'Surface Elevation', 'm')
#
# c:\Users\fagar\OneDrive\Desktop\FUNWAVE-TVD-Python-Tools\FUNWAVE_TOOLS_GSD\spectrogram_codes\spectra_1D.py in plot_spectra_1D(input_signal, time_vector, f, psd_data, y_label, y_units)
#      68     plt.xlabel('Freq (Hz)')
#      69     plt.ylabel(['Power/Freq (' + y_units + '^2/Hz)'])
# ---> 70     plt.ylim(psd_data.min(),psd_data.max())
#      71     plt.xlim([f[0],f[-1]])
#      72
#
# c:\Users\fagar\anaconda3\lib\site-packages\matplotlib\pyplot.py in ylim(*args, **kwargs)
#    1755     if not args and not kwargs:
#    1756         return ax.get_ylim()
# -> 1757     ret = ax.set_ylim(*args, **kwargs)
#    1758     return ret
#    1759
#
# c:\Users\fagar\anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4037                 top = old_top
#    4038
# -> 4039         if self.get_yscale() == 'log' and (bottom <= 0 or top <= 0):
#    4040             # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    4041             # so only grab the limits if we really need them.
#
# TypeError: '<=' not supported between instances of 'builtin_function_or_method' and 'int'
